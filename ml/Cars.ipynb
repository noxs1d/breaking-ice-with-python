# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
car_data=pd.read_csv("datasets/car/car_data.csv")
dekho=pd.read_csv("datasets/car/CAR DETAILS FROM CAR DEKHO.csv")
details=pd.read_csv("datasets/car/Car details v3.csv")
detail4=pd.read_csv("datasets/car/car details v4.csv")

# %%
car_data.rename(str.capitalize, axis="columns", inplace=True)

# %%
car_data.rename(columns={"Car_name":"Name","Kms_driven":"Km_driven"},inplace=True)

# %%
car_data
# Out:
#         Name  Year  Selling_price  Present_price  Km_driven Fuel_type  \
# 0       ritz  2014           3.35           5.59      27000    Petrol
# 1        sx4  2013           4.75           9.54      43000    Diesel
# 2       ciaz  2017           7.25           9.85       6900    Petrol
# 3    wagon r  2011           2.85           4.15       5200    Petrol
# 4      swift  2014           4.60           6.87      42450    Diesel
# ..       ...   ...            ...            ...        ...       ...
# 296     city  2016           9.50          11.60      33988    Diesel
# 297     brio  2015           4.00           5.90      60000    Petrol
# 298     city  2009           3.35          11.00      87934    Petrol
# 299     city  2017          11.50          12.50       9000    Diesel
# 300     brio  2016           5.30           5.90       5464    Petrol
#
#     Seller_type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
dekho.rename(str.capitalize, axis="columns", inplace=True)
dekho
# Out:
#                                      Name  Year  Selling_price  Km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         Fuel Seller_type Transmission         Owner
# ...

# %%
details.rename(str.capitalize, axis="columns", inplace=True)
details
# Out:
#                               Name  Year  Selling_price  Km_driven    Fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
detail4=pd.read_csv("datasets/car/car details v4.csv")
detail4.rename(str.capitalize, axis="columns", inplace=True)
detail4.rename(columns={"Fuel type":"Fuel","Price":"Selling_price","Kilometer":"Km_driven","Seller type":"Seller_type","Max power":"Max_power","Max torque":"Torque","Seating capacity":"Seat"}, inplace=True)

# %%
detail4["Name"]=detail4["Make"]+" "+detail4["Model"]

# %%
detail4.drop(["Make","Model"],axis=1, inplace=True)

# %%
detail4
# Out:
#       Selling_price  Year  Km_driven    Fuel Transmission    Location   Color  \
# 0            505000  2017      87150  Petrol       Manual        Pune    Grey
# 1            450000  2014      75000  Diesel       Manual    Ludhiana   White
# 2            220000  2011      67000  Petrol       Manual     Lucknow  Maroon
# 3            799000  2019      37500  Petrol       Manual   Mangalore     Red
# 4           1950000  2018      69000  Diesel       Manual      Mumbai    Grey
# ...             ...   ...        ...     ...          ...         ...     ...
# 2054         850000  2016      90300  Diesel       Manual       Surat   White
# 2055         275000  2014      83000  Petrol       Manual   Ahmedabad   White
# 2056         240000  2013      73000  Petrol       Manual       Thane  Silver
# 2057        4290000  2018      60474  Diesel    Automatic  Coimbatore   White
# 2058         670000  2017      72000  Diesel       Manual    Guwahati   White
#
# ...

# %%
df=pd.concat([details,detail4,car_data,dekho],ignore_index=True)

# %%
df
# Out:
#                                       Name  Year  Selling_price  Km_driven  \
# 0                   Maruti Swift Dzire VDI  2014       450000.0     145500
# 1             Skoda Rapid 1.5 TDI Ambition  2014       370000.0     120000
# 2                 Honda City 2017-2020 EXi  2006       158000.0     140000
# 3                Hyundai i20 Sportz Diesel  2010       225000.0     127000
# 4                   Maruti Swift VXI BSIII  2007       130000.0     120000
# ...                                    ...   ...            ...        ...
# 14823  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014       409999.0      80000
# 14824           Hyundai i20 Magna 1.4 CRDi  2014       409999.0      80000
# 14825                  Maruti 800 AC BSIII  2009       110000.0      83000
# 14826     Hyundai Creta 1.6 CRDi SX Option  2016       865000.0      90000
# 14827                     Renault KWID RXT  2016       225000.0      40000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14828 entries, 0 to 14827
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                14828 non-null  object
#  1   Year                14828 non-null  int64
#  2   Selling_price       14828 non-null  float64
#  3   Km_driven           14828 non-null  int64
#  4   Fuel                14527 non-null  object
#  5   Seller_type         14828 non-null  object
#  6   Transmission        14828 non-null  object
#  7   Owner               14828 non-null  object
#  8   Mileage             7907 non-null   object
#  9   Engine              9886 non-null   object
#  10  Max_power           9892 non-null   object
#  11  Torque              9885 non-null   object
#  12  Seats               7907 non-null   float64
#  13  Location            2059 non-null   object
#  14  Color               2059 non-null   object
# ...

# %%
df_cat=df.select_dtypes(include="object")

# %%
df_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14828 entries, 0 to 14827
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          14828 non-null  object
#  1   Fuel          14527 non-null  object
#  2   Seller_type   14828 non-null  object
#  3   Transmission  14828 non-null  object
#  4   Owner         14828 non-null  object
#  5   Mileage       7907 non-null   object
#  6   Engine        9886 non-null   object
#  7   Max_power     9892 non-null   object
#  8   Torque        9885 non-null   object
#  9   Location      2059 non-null   object
#  10  Color         2059 non-null   object
#  11  Drivetrain    1923 non-null   object
#  12  Fuel_type     301 non-null    object
# dtypes: object(13)
# memory usage: 1.5+ MB
